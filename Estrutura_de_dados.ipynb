# %%
print("Olá Mundo!")
# Out:
# Olá Mundo!

# %%
print("Estou aprendendo Python")
# Out:
# Estou aprendendo Python

# %%
"Estou aprendendo Python"
# Out:
# 'Estou aprendendo Python'

# %%
1 + 1
# Out:
# 2

# %%
10 - 2
# Out:
# 8

# %%
#ESSE É UM COMENTÁRIO EM PYTHON

# %%
#Multiplicação
2*2
# Out:
# 4

# %%
#Divisão
10 / 2
# Out:
# 5.0

# %%
a = 4
b = 6

# %%
a + b
# Out:
# 10

# %%
#Criando uma variável do tipo String
frase = "Python para análise de dados"

# %%
frase[0]
# Out:
# 'P'

# %%
 frase[0:q0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-51acbc83280a> in <module>
# ----> 1 frase[0:q0]
#
# NameError: name 'q0' is not defined

# %%
frase[0:10]
# Out:
# 'Python par'

# %%
frase[10:]
# Out:
# 'a análise de dados'

# %%
frase[:16]
# Out:
# 'Python para anál'

# %%
frase.count("dados")
# Out:
# 1

# %%
frase.lower()
# Out:
# 'python para análise de dados'

# %%
frase.upper()
# Out:
# 'PYTHON PARA ANÁLISE DE DADOS'

# %%
frase.replace("Python", "frase")
# Out:
# 'frase para análise de dados'

# %%
animais= [1,2,3]
animais
# Out:
# [1, 2, 3]

# %%
animais = ["cachorro", "gato", 12345, 6.5]
animais
# Out:
# ['cachorro', 'gato', 12345, 6.5]

# %%
animais[0]
# Out:
# 'cachorro'

# %%
animais[4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-25-2ff179066c67> in <module>
# ----> 1 animais[4]
#
# IndexError: list index out of range

# %%
animais[3]
# Out:
# 6.5

# %%
animais[0] = "papagaio"

# %%
animais
# Out:
# ['papagaio', 'gato', 12345, 6.5]

# %%
animais.remove("gato")

# %%
animais
# Out:
# ['papagaio', 12345, 6.5]

# %%
len(animais)
# Out:
# 3

# %%
"gato" in animals
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-f7be834e0991> in <module>
# ----> 1 "gato" in animals
#
# NameError: name 'animals' is not defined

# %%
"gato" in animais
# Out:
# False

# %%
lista=[500, 30, 100, 80, 10]

# %%
maz(lista)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-9e4ba3f7489d> in <module>
# ----> 1 maz(lista)
#
# NameError: name 'maz' is not defined

# %%
max(lista)
# Out:
# 500

# %%
min(lista)
# Out:
# 10

# %%
animais.append("leao")

# %%
animais
# Out:
# ['papagaio', 12345, 6.5, 'leao']

# %%
animais.extend(["cobra", 6])

# %%
animais
# Out:
# ['papagaio', 12345, 6.5, 'leao', 'cobra', 6]

# %%
animais.count("cachorro")
# Out:
# 0

# %%
lista.sort()

# %%
lista
# Out:
# [10, 30, 80, 100, 500]

# %%
#As tuplas usam parênteses como sintaxe
tp=("Banana", "Maça", 10, 50)

# %%
tp[0]
# Out:
# 'Banana'

# %%
tp[0]= "Laranja"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-7be7d294463d> in <module>
# ----> 1 tp[0]= "Laranja"
#
# TypeError: 'tuple' object does not support item assignment

# %%
tp.count("Maça")
# Out:
# 1

# %%
tp[0:2]
# Out:
# ('Banana', 'Maça')

# %%
#Para criar um dicionário utilizamos as {}
dc= {"Maça":20, "Banana":10, "Laranja":15, "Uva":5} #Dicionário trabalha com o conceito chave e valor

# %%
dc
# Out:
# {'Maça': 20, 'Banana': 10, 'Laranja': 15, 'Uva': 5}

# %%
dc{maça}
# Out:
#   File "<ipython-input-53-e777c544e4ef>", line 1
#     dc{maça}
#       ^
# SyntaxError: invalid syntax

# %%
#Acessando o valor de um dicionário atraves da chave
dc["Maça"]
# Out:
# 20

# %%
#Atualizando o valor da Maça
dc["Maça"] = 25
dc
# Out:
# {'Maça': 25, 'Banana': 10, 'Laranja': 15, 'Uva': 5}

# %%
#Retornando todas as chaver do dicionário
dc.keys()
# Out:
# dict_keys(['Maça', 'Banana', 'Laranja', 'Uva'])

# %%
#Retornando os valores do dicionário
dc.values()
# Out:
# dict_values([25, 10, 15, 5])

# %%
#Verificando se já existe uma chave no dicionário e caso não exista inserir
dc.setdefault("Limão", 22)
# Out:
# 22

# %%
dc
# Out:
# {'Maça': 25, 'Banana': 10, 'Laranja': 15, 'Uva': 5, 'Limão': 22}
